# %% [markdown]
# ## **🫱고령 남성의 손 구조 유형 분류 – 손가락 마디 및 손둘레 기반 군집 분석**

# %% [markdown]
# ### **📜분석절차**
# 1. **데이터전처리 - 고령 남성 추출, 변수선택, 결측치처리**
# 2. **아노바분산분석(70–74세, 75–79세, 80–85세) 연령이 손 구조에 영향을 주는가?**
# 4. **정규화 - 변수 표준화 z-score (평균0 표준편차1)**
# 5. **요인분석 - 비슷한 변수끼리 묶음**
# 6. **군집분석 - 손 구조 유형 분류**
# 7. **군집해석**
# 8. **결론**

# %% [markdown]
# ### **1. 데이터전처리 - 고령 남성 추출, 변수선택, 결측치처리**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

df = pd.read_csv('C:/Users/FORYOUCOM/Desktop/인체치수조사_치수데이터(공개용)/손_8차 인체치수조사(2020~23)_치수데이터(공개용).csv', 
                 encoding='utf-8')
df.drop([
    # 첫마디 관련 길이 - 중간/끝마디와 유사 패턴, 정보 중복
    '343. 손목중심-엄지손가락첫마디길이',
    '344. 손목중심-검지손가락첫마디길이',
    '346. 손목중심-반지손가락첫마디길이',
    '347. 손목중심-새끼손가락첫마디길이',

    # 복합구간 길이 - 측정 지점이 복잡하고 해석 어려움
    '342. 손목가쪽-엄지손가락손끝길이',
    '348. 엄지손가락첫마디-검지손가락첫마디직선길이',

    # 첫마디 둘레 - 중복 정보 많고 영향 낮음으로 판단
    '367. 엄지손가락첫마디둘레',
    '368. 검지손가락첫마디둘레',
    '369. 가운데손가락첫마디둘레',
    '370. 반지손가락첫마디둘레',
    '371. 새끼손가락첫마디둘레'
], axis=1, inplace=True)

#남성만 필터링
df= df.loc[df['성별']=='남', :]

#결측치 확인결과 -> X
# df.isnull().sum()

# %% [markdown]
# 🔎**분석항목**
#
# - 너비
#     - 349검지손가락끝마디너비 / 350가운데손가락끝마디너비 / 351반지손가락끝마디너비 / 352새끼손가락끝마디너비 /353검지손가락중간마디너비 / 354가운데손가락중간마디너비 / 355반지손가락중간마디너비 / 356새끼손가락중간마디너비
#
# - 둘레
#     - 359검지손가락끝마디둘레 / 360가운데손가락끝마디둘레 / 361반지손가락끝마디둘레 / 362새끼손가락끝마디둘레 /363검지손가락중간마디둘레 / 364가운데손가락중간마디둘레 / 365반지손가락중간마디둘레 / 366새끼손가락중간마디둘레 /372손둘레
#
# - 길이
#     - 336손직선길이 / 338검지손가락직선길이 / 339가운데손가락직선길이 / 340반지손가락직선길이 / 341새끼손가락직선길이 /345손바닥직선길이 / 357손안쪽가쪽직선길이
#
# - 두께
#     - 373손두께 / 374손두께(2/3 지점)

# %% [markdown]
# ### **2. 정규화 - 변수 표준화(평균0 표준편차1)**

# %% [markdown]
# ### **3. 요인분석 - 비슷한 변수끼리 묶음**

# %% [markdown]
# ### **4. 군집분석 - 손 구조 유형 분류**

# %% [markdown]
# ### **5. 군집해석**

# %% [markdown]
# ### **6. 결론**
